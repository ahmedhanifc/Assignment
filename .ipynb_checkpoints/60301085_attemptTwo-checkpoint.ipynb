# %% [markdown]
# # DSAI 2201 Winter 2024 Assignment

# %%
NAME = 'Ahmed Hanif - 60301085'

COLLABORATORS = ""

# %% [markdown]
# ## Assignment 1 - Data Analysis
# **(20 points in total)**

# %% [markdown]
# In Assignments part 1 & part 2 we will go through the entire journey of a small data science project.
#
# More details about the dataset can be found in the Kaggle website in the following links: https://www.kaggle.com/datasets/reihanenamdari/breast-cancer
#
# But a modified version of the dataset was attached in the dropbox, please use it to answer this assignment

# %% [markdown]
# **Question 1.**  _(2 points)_
# * A) Analyze the distribution of death events cases among the patients and the race. calculate their respective numbers and percentages.  _(0.5 points)_
# * B) Compute descriptive statistics of the data. Comment on the results.  _(0.75 points)_
# * C) Analyze the skew and the kurtosis of medical variables distributions(Numbers & Graphs). Comment on the results.  _(0.75  points)_
#
# **Question 2.**  _(2 points)_
# * Use univariate plots  to analyze patterns in each of the medical variables with respect to the outcome (death status). What categories of patients( race and marital status) were most likely to die from breast cancer? . (2 points)
#
#
# **Question 3.**  _(2 points)_
# * Use multivariate plots to:
#    * A) Analyze the relationship between medical variables. Comment on the results  _(1 points)_
#    * B) Identify potential factors that can predict Death event in married patients. Comment on the results.  _(1 points)_
#
# **Question 4.**  _(3 points)_
# * Identify and remove any outliers in the medical variables. Explain the rationale for identifying and removing outliers.  _(3 points)_
#
# **Question 5.**  _(3 points)_
# * How did you treat missing values for the attributes that you included in the analysis ? Provide a detailed explanation in the comments._(3 points)_
#
# **Question 6.**  _(3 points)_
# * The dataset contains  contains alot of zeros, identify which attributes cannot be 0 medically speaking, and impute them, while explaining the rational behind it._(3 points)_
#
#
# **Question 7.**  _(2 points)_
# * Identify the attibutes that will need rescalling ( with explanation ), apply one of the rescalling techniques we have seen in our course and explain your rational. _(2 points)_
#
# **Question 8.**  _(3 points)_
# * Through an extensive research, provide additional attributes that you can create that will enhance your dataset, explain the logic behind it, and add them to your data, _(1.5 points)_
# * identify the most irrelevant attribute(s), and exclude them from your project for the next steps  _(1.5 points)_

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import scipy

# %%
df_verOne = pd.read_csv('Breast_Cancer-Winter2024.csv')

# %% [markdown]
# <h1>Start of Data Cleaning</h1>

# %% [markdown]
# <h2>Renaming Columns</h2>

# %%
df_columns = df_verOne.columns
new_column = []
for column in df_columns:
    column = column.lower().strip().replace(' ', '_')
    new_column.append(column)
df_verOne.columns = new_column
df_verOne.rename(columns = {'t_stage_' : 't_stage', 'reginol_node_positive': 'regional_node_positive'}, inplace = True)
df_columns = df_verOne.columns
df_columns
# Out:
# Index(['age', 'race', 'marital_status', 't_stage', 'n_stage', '6th_stage',
#        'differentiate', 'grade', 'a_stage', 'tumor_size', 'estrogen_status',
#        'progesterone_status', 'regional_node_examined',
#        'regional_node_positive', 'survival_months', 'status'],
#       dtype='object')

# %%
df_verOne.head(60)
# Out:
#     age   race marital_status t_stage n_stage 6th_stage  \
# 0    68  White        Married      T1      N1       IIA
# 1    50  White        Married      T2      N2      IIIA
# 2    58  White       Divorced      T3      N3      IIIC
# 3    58  White        Married      T1      N1       IIA
# 4    47  White        Married      T2      N1       IIB
# 5    51  White        Single       T1      N1       IIA
# 6    51  White        Married     NaN      N1       IIA
# 7    40  White        Married     NaN      N1       IIB
# 8    40  White       Divorced     NaN      N3      IIIC
# 9    69  White        Married     NaN      N3      IIIC
# 10   68  White        Widowed     NaN      N1       IIA
# 11   46  White        Married      T3      N1      IIIA
# 12   65  White        Married      T2      N1       IIB
# 13   48  White        Married      T1      N2      IIIA
# 14   62  White       Divorced      T2      N3      IIIC
# 15   61  White        Married      T1      N1       IIA
# 16   56  White        Single       T2      N1       IIB
# 17   43  White        Married      T2      N1       IIB
# 18   48  Black       Divorced      T2      N1       IIB
# 19   60  White       Divorced      T2      N1       IIB
# 20   48  Other        Married      T2      N1       IIB
# 21   57  White        Married      T2      N2      IIIA
# 22   55  White        Single       T2      N1       IIB
# 23   48  White        Married      T3      N1      IIIA
# 24   62  White        Married      T1      N3      IIIC
# 25   63  White        Married      T2      N3      IIIC
# 26   48  White        Married      T2      N3      IIIC
# 27   46  White        Married      T1      N1       IIA
# 28   57  White       Divorced      T2      N2      IIIA
# 29   66  White        Married      T2      N1       IIB
# 30   47  White      Separated      T2      N1       IIB
# 31   53  White        Married      T1      N1       IIA
# 32   59  White        Single       T1      N1       IIA
# 33   60  White        Married      T1      N1       IIA
# 34   46  Other        Married      T2      N3      IIIC
# 35   51  White        Married      T1      N1       IIA
# 36   54  White        Married      T2      N2      IIIA
# 37   51  White        Married      T1      N1       IIA
# 38   49  White        Married      T2      N1       IIB
# 39   51  Other       Divorced      T2      N2      IIIA
# 40   57  White        Single       T3      N3      IIIC
# 41   64  White        Married      T1      N1       IIA
# 42   62  Other        Married      T2      N1       IIB
# 43   53  Black        Single       T2      N2      IIIA
# 44   55  White        Married      T1      N1       IIA
# 45   66  White        Married      T3      N2      IIIA
# 46   42  White        Married      T1      N3      IIIC
# 47   62  White        Widowed      T1      N1       IIA
# 48   53  White        Married      T2      N2      IIIA
# 49   69  White        Widowed      T1      N1       IIA
# 50   37  White        Single       T2      N1       IIB
# 51   69  White        Married      T3      N1      IIIA
# 52   60  Black        Married      T3      N1      IIIA
# 53   63  White        Married      T3      N1      IIIA
# 54   57  White        Married      T1      N1       IIA
# 55   55  White        Married      T1      N1       IIA
# 56   62  White        Married      T2      N1       IIB
# 57   50  White        Married      T1      N1       IIA
# 58   50  White        Married      T1      N1       IIA
# 59   55  White        Married      T1      N1       IIA
#
#                 differentiate grade   a_stage  tumor_size estrogen_status  \
# 0       Poorly differentiated     3  Regional         4.0        Positive
# 1   Moderately differentiated     2  Regional        35.0        Positive
# 2   Moderately differentiated     2  Regional        63.0        Positive
# 3       Poorly differentiated     3  Regional        18.0        Positive
# 4                         NaN     3  Regional        41.0        Positive
# 5                         NaN     2  Regional        20.0        Positive
# 6                         NaN     1  Regional         8.0        Positive
# 7                         NaN     2  Regional        30.0        Positive
# 8                         NaN     3  Regional       103.0        Positive
# 9                         NaN     1   Distant        32.0        Positive
# 10  Moderately differentiated     2  Regional        13.0        Positive
# 11      Poorly differentiated     3  Regional        59.0        Negative
# 12      Poorly differentiated     3  Regional        35.0        Positive
# 13      Poorly differentiated     3  Regional        15.0        Positive
# 14  Moderately differentiated     2  Regional         NaN        Positive
# 15  Moderately differentiated     2  Regional         NaN        Positive
# 16  Moderately differentiated     2  Regional         NaN        Positive
# 17  Moderately differentiated     2  Regional         NaN        Positive
# 18  Moderately differentiated     2  Regional         NaN        Positive
# 19  Moderately differentiated     2  Regional         NaN        Negative
# 20        Well differentiated     1  Regional        30.0        Positive
# 21  Moderately differentiated     2  Regional        40.0        Positive
# 22      Poorly differentiated     3  Regional        29.0        Positive
# 23      Poorly differentiated     3  Regional        70.0        Positive
# 24      Poorly differentiated     3  Regional        20.0        Positive
# 25  Moderately differentiated     2  Regional        22.0        Positive
# 26      Poorly differentiated     3  Regional        50.0        Positive
# 27        Well differentiated     1  Regional        17.0        Positive
# 28        Well differentiated     1  Regional        25.0        Positive
# 29      Poorly differentiated     3  Regional        21.0        Positive
# 30        Well differentiated     1  Regional        40.0        Positive
# 31  Moderately differentiated     2  Regional        15.0        Positive
# 32  Moderately differentiated     2  Regional        15.0        Positive
# 33  Moderately differentiated     2  Regional        20.0        Positive
# 34  Moderately differentiated     2  Regional        30.0        Positive
# 35        Well differentiated     1  Regional        10.0        Positive
# 36  Moderately differentiated     2  Regional        27.0        Positive
# 37  Moderately differentiated     2  Regional        18.0        Positive
# 38  Moderately differentiated     2  Regional        35.0        Positive
# 39  Moderately differentiated     2  Regional        23.0        Positive
# 40  Moderately differentiated     2  Regional        70.0        Positive
# 41  Moderately differentiated     2  Regional        17.0        Positive
# 42  Moderately differentiated     2  Regional        21.0        Positive
# 43      Poorly differentiated     3  Regional        23.0        Positive
# 44  Moderately differentiated     2  Regional         5.0        Positive
# 45  Moderately differentiated     2  Regional        51.0        Positive
# 46  Moderately differentiated     2  Regional         9.0        Negative
# 47  Moderately differentiated     2  Regional        15.0        Positive
# 48  Moderately differentiated     2  Regional        32.0        Positive
# 49  Moderately differentiated     2  Regional         5.0        Positive
# 50  Moderately differentiated     2  Regional        23.0        Positive
# 51  Moderately differentiated     2  Regional        55.0        Positive
# 52      Poorly differentiated     3  Regional       120.0        Positive
# 53        Well differentiated     1  Regional        77.0        Positive
# 54  Moderately differentiated     2  Regional         2.0        Positive
# 55  Moderately differentiated     2  Regional        11.0        Positive
# 56  Moderately differentiated     2  Regional        25.0        Positive
# 57  Moderately differentiated     2  Regional        18.0        Positive
# 58  Moderately differentiated     2  Regional        15.0        Positive
# 59  Moderately differentiated     2  Regional        12.0        Positive
#
#    progesterone_status  regional_node_examined  regional_node_positive  \
# 0             Positive                      24                       1
# 1             Positive                      14                       5
# 2             Positive                      14                       7
# 3             Positive                       2                       1
# 4             Positive                       3                       1
# 5             Positive                      18                       2
# 6             Positive                      11                       1
# 7             Positive                       9                       1
# 8             Positive                      20                      18
# 9             Positive                      21                      12
# 10            Positive                       9                       1
# 11            Negative                      11                       3
# 12            Positive                      13                       3
# 13            Positive                      23                       7
# 14            Positive                      16                      14
# 15            Positive                      20                       1
# 16            Positive                       1                       1
# 17            Positive                      22                       1
# 18            Positive                      16                       1
# 19            Negative                      20                       1
# 20            Positive                      15                       2
# 21                   0                      15                       5
# 22                   0                       4                       1
# 23                   0                      18                       1
# 24                   0                      26                      22
# 25                   0                      31                      17
# 26            Positive                      25                      23
# 27            Positive                      14                       1
# 28            Negative                      14                       4
# 29            Positive                      10                       1
# 30            Positive                       3                       1
# 31            Positive                       5                       1
# 32            Positive                       6                       1
# 33            Negative                      19                       3
# 34            Positive                      19                      10
# 35            Positive                       9                       2
# 36            Negative                      21                       6
# 37            Positive                      14                       2
# 38            Positive                      10                       2
# 39            Positive                      15                       5
# 40            Positive                      12                      12
# 41            Positive                      12                       2
# 42            Negative                       2                       1
# 43            Negative                      15                       6
# 44            Positive                      11                       2
# 45            Positive                      10                       5
# 46            Negative                      15                       2
# 47            Positive                      12                       1
# 48            Positive                      16                       9
# 49            Positive                       8                       3
# 50            Positive                      17                       3
# 51            Negative                       9                       1
# 52            Negative                       7                       1
# 53            Negative                      20                       2
# 54            Negative                      16                       1
# 55            Positive                      13                       1
# 56            Positive                      19                       1
# 57            Negative                      49                       1
# 58            Positive                      15                       1
# 59            Positive                      17                       2
#
#     survival_months status
# 0              60.0  Alive
# 1              62.0  Alive
# 2              75.0  Alive
# 3               NaN  Alive
# 4               NaN  Alive
# 5               NaN  Alive
# 6               NaN  Alive
# 7               NaN   Dead
# 8               NaN  Alive
# 9               NaN  Alive
# 10             64.0   Dead
# 11             92.0  Alive
# 12             56.0  Alive
# 13             38.0  Alive
# 14              0.0  Alive
# 15              0.0  Alive
# 16              0.0  Alive
# 17              0.0  Alive
# 18              0.0  Alive
# 19              0.0  Alive
# 20              0.0  Alive
# 21             50.0  Alive
# 22             78.0  Alive
# 23            102.0  Alive
# 24             98.0  Alive
# 25             70.0  Alive
# 26            102.0  Alive
# 27             82.0  Alive
# 28             64.0  Alive
# 29             86.0  Alive
# 30             52.0  Alive
# 31             49.0  Alive
# 32             90.0  Alive
# 33             62.0  Alive
# 34             31.0  Alive
# 35             77.0  Alive
# 36             37.0  Alive
# 37            103.0  Alive
# 38             82.0  Alive
# 39            105.0  Alive
# 40             42.0   Dead
# 41             61.0  Alive
# 42             86.0  Alive
# 43             84.0  Alive
# 44             63.0  Alive
# 45             90.0  Alive
# 46             39.0   Dead
# 47             59.0  Alive
# 48             82.0  Alive
# 49             82.0  Alive
# 50             71.0  Alive
# 51             71.0  Alive
# 52             86.0  Alive
# 53             70.0  Alive
# 54             74.0  Alive
# 55             73.0  Alive
# 56             91.0  Alive
# 57            106.0  Alive
# 58             73.0  Alive
# 59             77.0  Alive

# %% [markdown]
# <p>Need to Fix progesterone_status column</p>
# <p><b>t_stage</b> is categorical -> Replace with Mode</p>
# <b> differentiate </b> is Categorical -> Replace with Mode
# <p></p><b> tumor_size and survivor_months</b> is numerical -> Analyze if Data is skewed or not. If Skewed -> Median , else mean</p>

# %%
df_verOne.dtypes
# Out:
# age                         int64
# race                       object
# marital_status             object
# t_stage                    object
# n_stage                    object
# 6th_stage                  object
# differentiate              object
# grade                      object
# a_stage                    object
# tumor_size                float64
# estrogen_status            object
# progesterone_status        object
# regional_node_examined      int64
# regional_node_positive      int64
# survival_months           float64
# status                     object
# dtype: object

# %%
df_verOne.isnull().sum()
# Out:
# age                       0
# race                      0
# marital_status            0
# t_stage                   5
# n_stage                   0
# 6th_stage                 0
# differentiate             6
# grade                     0
# a_stage                   0
# tumor_size                6
# estrogen_status           0
# progesterone_status       0
# regional_node_examined    0
# reginol_node_positive     0
# survival_months           7
# status                    0
# dtype: int64

# %%
def calculate_bin_edges(column, bin_boundary):
    return np.arange(0,column.max() + bin_boundary, bin_boundary)

# %% [markdown]
# <p> Drawing Graphics in order to figure out the distribution</p>
# <p> What does the binning do?</p>

# %%
plt.figure(figsize=(15,7))
plt.subplot(2,2,1)
sb.kdeplot(df_verOne[['tumor_size','survival_months']]);
plt.subplot(2,2,2)
sb.histplot(df_verOne['tumor_size'], bins = calculate_bin_edges(df_verOne['tumor_size'], 10))
plt.subplot(2,2,3)
sb.histplot(df_verOne['survival_months'], bins = calculate_bin_edges(df_verOne['survival_months'], 5))
# Out:
# /home/ahmedhanifc/miniconda3/envs/learningDSAI/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/ahmedhanifc/miniconda3/envs/learningDSAI/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/ahmedhanifc/miniconda3/envs/learningDSAI/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='survival_months', ylabel='Count'>

# %% [markdown]
# <p><b>Data is Skewed in Both Cases, Hence we will be using the median to replace missing values</b></p>

# %%
df_verOne.isna().sum()
# Out:
# age                       0
# race                      0
# marital_status            0
# t_stage                   5
# n_stage                   0
# 6th_stage                 0
# differentiate             6
# grade                     0
# a_stage                   0
# tumor_size                6
# estrogen_status           0
# progesterone_status       0
# regional_node_examined    0
# reginol_node_positive     0
# survival_months           7
# status                    0
# dtype: int64

# %%
df_verTwo = df_verOne.copy()
df_verTwo_columns = df_verTwo.columns
for column in df_verTwo_columns:
    if (column == 'tumor_size') | (column == 'survival_months'):
        df_verTwo[column].fillna(df_verTwo[column].median(), inplace = True)
    elif (column == 't_stage') | (column == 'differentiate'):
        df_verTwo[column].fillna(df_verTwo[column].mode()[0], inplace = True)

# %%
df_verTwo.head()
# Out:
#    age   race marital_status t_stage n_stage 6th_stage  \
# 0   68  White        Married      T1      N1       IIA
# 1   50  White        Married      T2      N2      IIIA
# 2   58  White       Divorced      T3      N3      IIIC
# 3   58  White        Married      T1      N1       IIA
# 4   47  White        Married      T2      N1       IIB
#
#                differentiate grade   a_stage  tumor_size estrogen_status  \
# 0      Poorly differentiated     3  Regional         4.0        Positive
# 1  Moderately differentiated     2  Regional        35.0        Positive
# 2  Moderately differentiated     2  Regional        63.0        Positive
# 3      Poorly differentiated     3  Regional        18.0        Positive
# 4  Moderately differentiated     3  Regional        41.0        Positive
#
#   progesterone_status  regional_node_examined  regional_node_positive  \
# 0            Positive                      24                       1
# 1            Positive                      14                       5
# 2            Positive                      14                       7
# 3            Positive                       2                       1
# 4            Positive                       3                       1
#
#    survival_months status
# 0             60.0  Alive
# 1             62.0  Alive
# 2             75.0  Alive
# 3             73.0  Alive
# 4             73.0  Alive

# %% [markdown]
# <b>Changing objects into appropriate category dtype </b>
# <p> Why?</p>

# %%
for dataframe in df_verTwo:
    if(df_verTwo[dataframe].dtype) == 'object':
        df_verTwo[dataframe].astype('category')

# %%
# df_verTwo[['status','estrogen_status','progesterone_status','a_stage','differentiate','n_stage','t_stage','marital_status','race']]=df_verTwo[['status','estrogen_status','progesterone_status','a_stage','differentiate','n_stage','t_stage','marital_status','race']].astype('category')

# %%
df_verTwo.dtypes
# Out:
# age                         int64
# race                       object
# marital_status             object
# t_stage                    object
# n_stage                    object
# 6th_stage                  object
# differentiate              object
# grade                      object
# a_stage                    object
# tumor_size                float64
# estrogen_status            object
# progesterone_status        object
# regional_node_examined      int64
# reginol_node_positive       int64
# survival_months           float64
# status                     object
# dtype: object

# %% [markdown]
# <b> Checking for Duplicates</b>

# %%
df_verTwo.duplicated().sum()
# Out:
# 0

# %%
df_verTwo.drop_duplicates(inplace=True)

# %%
df_verTwo.sample()
# Out:
#       age   race marital_status t_stage n_stage 6th_stage  \
# 1569   53  White        Married      T1      N1       IIA
#
#                   differentiate grade   a_stage  tumor_size estrogen_status  \
# 1569  Moderately differentiated     2  Regional        20.0        Negative
#
#      progesterone_status  regional_node_examined  reginol_node_positive  \
# 1569            Negative                      11                      1
#
#       survival_months status
# 1569             66.0  Alive

# %% [markdown]
# <p><b>Apparently,</b> progesterone_status has some 0 values. Need to convert those into Negative</p>
# <p>Found out about this by trying to One Hot Encode it. There was an extra column with the progesterone_status_0 name</p>

# %%
df_verTwo['progesterone_status'].replace('0', 'Negative', inplace = True)
df_verTwo['progesterone_status'].value_counts()
# Out:
# progesterone_status
# Positive    3322
# Negative     702
# Name: count, dtype: int64

# %% [markdown]
# <h3>Encoding</h2>

# %% [markdown]
# <p><b>One Hot Encoding:</b> Performed On Nominal Variables</p>
# <p> Converting Categorical Variables into Numerical so I can perform Statistical Analysis on them such as finding total percentage</p>

# %%
df_verThree = df_verTwo.copy()
df_verThree = pd.get_dummies(df_verThree, columns = ['status','progesterone_status','estrogen_status'], prefix = ['status','progesterone_status','estrogen_status'])

# %%
df_verThree.sample(50)
# Out:
#       age   race marital_status t_stage n_stage 6th_stage  \
# 852    46  White        Married      T2      N1       IIB
# 3141   50  White        Married      T1      N1       IIA
# 3938   48  White        Widowed      T2      N1       IIB
# 2816   54  White        Married      T1      N1       IIA
# 1190   55  White        Married      T3      N2      IIIA
# 61     51  White        Married      T1      N1       IIA
# 2898   39  Other        Married      T3      N1      IIIA
# 1845   35  Black        Single       T1      N1       IIA
# 2091   49  White        Married      T2      N2      IIIA
# 2107   59  White        Married      T4      N2      IIIB
# 2174   54  White        Married      T1      N2      IIIA
# 3240   48  Other        Married      T1      N1       IIA
# 1762   42  White        Married      T1      N2      IIIA
# 1903   43  White        Married      T1      N1       IIA
# 2499   56  White        Married      T2      N1       IIB
# 1807   54  White        Married      T2      N3      IIIC
# 1033   62  White        Married      T2      N3      IIIC
# 3886   54  White        Married      T2      N1       IIB
# 219    50  White        Married      T3      N3      IIIC
# 1676   40  Other        Married      T1      N1       IIA
# 3267   67  White        Married      T2      N3      IIIC
# 2196   67  White        Married      T2      N1       IIB
# 3614   44  Other        Married      T2      N1       IIB
# 2631   48  White        Married      T2      N1       IIB
# 3830   60  White        Married      T2      N2      IIIA
# 3066   51  Other        Married      T2      N1       IIB
# 565    58  White        Married      T2      N2      IIIA
# 1342   53  White        Single       T2      N1       IIB
# 2264   59  White        Married      T1      N1       IIA
# 1775   53  White       Divorced      T1      N2      IIIA
# 1374   50  Other       Divorced      T1      N1       IIA
# 3962   62  White        Widowed      T2      N2      IIIA
# 1304   55  White        Married      T1      N1       IIA
# 3823   51  Other        Married      T1      N2      IIIA
# 3504   65  White        Married      T2      N2      IIIA
# 17     43  White        Married      T2      N1       IIB
# 1236   47  White        Married      T1      N1       IIA
# 585    58  White        Married      T4      N2      IIIB
# 1720   69  White        Married      T1      N1       IIA
# 1268   54  Black        Single       T2      N1       IIB
# 10     68  White        Widowed      T2      N1       IIA
# 2512   48  White        Single       T1      N1       IIA
# 3211   43  Other        Single       T3      N1      IIIA
# 386    40  White        Married      T1      N1       IIA
# 2832   46  White        Married      T1      N1       IIA
# 165    68  Other        Widowed      T3      N1      IIIA
# 679    62  White        Married      T2      N2      IIIA
# 121    43  White       Divorced      T4      N1      IIIB
# 334    53  White        Widowed      T2      N1       IIB
# 1034   55  White        Married      T1      N1       IIA
#
#                   differentiate grade   a_stage  tumor_size  \
# 852   Moderately differentiated     2  Regional        35.0
# 3141      Poorly differentiated     3  Regional        20.0
# 3938  Moderately differentiated     2  Regional        30.0
# 2816        Well differentiated     1  Regional        10.0
# 1190        Well differentiated     1  Regional         6.0
# 61    Moderately differentiated     2  Regional        17.0
# 2898      Poorly differentiated     3  Regional        70.0
# 1845      Poorly differentiated     3  Regional        18.0
# 2091        Well differentiated     1  Regional        22.0
# 2107      Poorly differentiated     3  Regional        78.0
# 2174  Moderately differentiated     2  Regional        16.0
# 3240  Moderately differentiated     2  Regional        20.0
# 1762  Moderately differentiated     2  Regional        15.0
# 1903  Moderately differentiated     2  Regional        11.0
# 2499  Moderately differentiated     2  Regional        40.0
# 1807      Poorly differentiated     3  Regional        21.0
# 1033      Poorly differentiated     3  Regional        21.0
# 3886  Moderately differentiated     2  Regional        25.0
# 219       Poorly differentiated     3   Distant        75.0
# 1676  Moderately differentiated     2  Regional        15.0
# 3267  Moderately differentiated     2  Regional        21.0
# 2196      Poorly differentiated     3  Regional        26.0
# 3614  Moderately differentiated     2  Regional        25.0
# 2631  Moderately differentiated     2  Regional        34.0
# 3830  Moderately differentiated     2  Regional        23.0
# 3066      Poorly differentiated     3  Regional        25.0
# 565       Poorly differentiated     3  Regional        50.0
# 1342  Moderately differentiated     2  Regional        23.0
# 2264  Moderately differentiated     2  Regional        11.0
# 1775      Poorly differentiated     3  Regional        15.0
# 1374  Moderately differentiated     2  Regional        14.0
# 3962      Poorly differentiated     3  Regional        25.0
# 1304  Moderately differentiated     2  Regional        11.0
# 3823  Moderately differentiated     2  Regional        12.0
# 3504  Moderately differentiated     2  Regional        35.0
# 17    Moderately differentiated     2  Regional        25.0
# 1236  Moderately differentiated     2  Regional        16.0
# 585   Moderately differentiated     2  Regional        81.0
# 1720  Moderately differentiated     2  Regional        18.0
# 1268  Moderately differentiated     2  Regional        38.0
# 10    Moderately differentiated     2  Regional        13.0
# 2512  Moderately differentiated     2  Regional        15.0
# 3211  Moderately differentiated     2  Regional        55.0
# 386       Poorly differentiated     3  Regional        18.0
# 2832        Well differentiated     1  Regional        12.0
# 165   Moderately differentiated     2  Regional        62.0
# 679   Moderately differentiated     2  Regional        25.0
# 121       Poorly differentiated     3  Regional        35.0
# 334         Well differentiated     1  Regional        32.0
# 1034  Moderately differentiated     2  Regional        20.0
#
#       regional_node_examined  regional_node_positive  survival_months  \
# 852                       19                       3            102.0
# 3141                      16                       1             45.0
# 3938                       4                       1             49.0
# 2816                       5                       1            101.0
# 1190                       9                       7             50.0
# 61                        12                       1             49.0
# 2898                      12                       3             44.0
# 1845                       8                       1             21.0
# 2091                       8                       5              8.0
# 2107                      12                       8             43.0
# 2174                       7                       4             95.0
# 3240                       6                       1            106.0
# 1762                      10                       5            107.0
# 1903                      25                       2            103.0
# 2499                      21                       1             92.0
# 1807                      29                      12             67.0
# 1033                      18                      11             14.0
# 3886                      12                       3             66.0
# 219                       27                      27             23.0
# 1676                      14                       2             72.0
# 3267                      29                      21             73.0
# 2196                      12                       1             76.0
# 3614                       5                       3             61.0
# 2631                      18                       1             60.0
# 3830                      26                       8             52.0
# 3066                      14                       2             50.0
# 565                       14                       4             19.0
# 1342                       3                       2             83.0
# 2264                      11                       1             64.0
# 1775                      14                       8             53.0
# 1374                       4                       1             97.0
# 3962                      18                       4             56.0
# 1304                      13                       2             71.0
# 3823                      16                       6             80.0
# 3504                      16                       4             50.0
# 17                        22                       1              0.0
# 1236                       5                       1             68.0
# 585                       19                       6            107.0
# 1720                      20                       1             60.0
# 1268                       5                       2             69.0
# 10                         9                       1             64.0
# 2512                      19                       3             99.0
# 3211                      25                       2             98.0
# 386                       16                       1             91.0
# 2832                       1                       1             86.0
# 165                        3                       1             54.0
# 679                       13                       4              4.0
# 121                       15                       3             79.0
# 334                       13                       1             68.0
# 1034                       2                       1             57.0
#
#       status_Alive  status_Dead  progesterone_status_0  \
# 852           True        False                  False
# 3141         False         True                  False
# 3938          True        False                  False
# 2816          True        False                  False
# 1190          True        False                  False
# 61            True        False                  False
# 2898         False         True                  False
# 1845         False         True                  False
# 2091          True        False                  False
# 2107         False         True                  False
# 2174          True        False                  False
# 3240          True        False                  False
# 1762          True        False                  False
# 1903          True        False                  False
# 2499          True        False                  False
# 1807          True        False                  False
# 1033         False         True                  False
# 3886          True        False                  False
# 219          False         True                  False
# 1676          True        False                  False
# 3267          True        False                  False
# 2196          True        False                  False
# 3614          True        False                  False
# 2631          True        False                  False
# 3830          True        False                  False
# 3066          True        False                  False
# 565          False         True                  False
# 1342          True        False                  False
# 2264          True        False                  False
# 1775          True        False                  False
# 1374          True        False                  False
# 3962          True        False                  False
# 1304          True        False                  False
# 3823          True        False                  False
# 3504         False         True                  False
# 17            True        False                  False
# 1236          True        False                  False
# 585           True        False                  False
# 1720          True        False                  False
# 1268          True        False                  False
# 10           False         True                  False
# 2512          True        False                  False
# 3211          True        False                  False
# 386           True        False                  False
# 2832          True        False                  False
# 165           True        False                  False
# 679          False         True                  False
# 121           True        False                  False
# 334           True        False                  False
# 1034          True        False                  False
#
#       progesterone_status_Negative  progesterone_status_Positive  \
# 852                          False                          True
# 3141                          True                         False
# 3938                         False                          True
# 2816                         False                          True
# 1190                         False                          True
# 61                            True                         False
# 2898                         False                          True
# 1845                          True                         False
# 2091                         False                          True
# 2107                         False                          True
# 2174                         False                          True
# 3240                         False                          True
# 1762                         False                          True
# 1903                         False                          True
# 2499                         False                          True
# 1807                          True                         False
# 1033                          True                         False
# 3886                         False                          True
# 219                           True                         False
# 1676                         False                          True
# 3267                         False                          True
# 2196                         False                          True
# 3614                         False                          True
# 2631                         False                          True
# 3830                         False                          True
# 3066                          True                         False
# 565                           True                         False
# 1342                         False                          True
# 2264                         False                          True
# 1775                         False                          True
# 1374                         False                          True
# 3962                         False                          True
# 1304                         False                          True
# 3823                         False                          True
# 3504                          True                         False
# 17                           False                          True
# 1236                         False                          True
# 585                          False                          True
# 1720                         False                          True
# 1268                         False                          True
# 10                           False                          True
# 2512                         False                          True
# 3211                         False                          True
# 386                          False                          True
# 2832                         False                          True
# 165                          False                          True
# 679                          False                          True
# 121                          False                          True
# 334                          False                          True
# 1034                         False                          True
#
#       estrogen_status_Negative  estrogen_status_Positive
# 852                      False                      True
# 3141                     False                      True
# 3938                     False                      True
# 2816                     False                      True
# 1190                     False                      True
# 61                       False                      True
# 2898                     False                      True
# 1845                      True                     False
# 2091                     False                      True
# 2107                     False                      True
# 2174                     False                      True
# 3240                     False                      True
# 1762                     False                      True
# 1903                     False                      True
# 2499                     False                      True
# 1807                      True                     False
# 1033                      True                     False
# 3886                     False                      True
# 219                       True                     False
# 1676                     False                      True
# 3267                     False                      True
# 2196                     False                      True
# 3614                     False                      True
# 2631                     False                      True
# 3830                     False                      True
# 3066                     False                      True
# 565                       True                     False
# 1342                     False                      True
# 2264                     False                      True
# 1775                     False                      True
# 1374                     False                      True
# 3962                     False                      True
# 1304                     False                      True
# 3823                     False                      True
# 3504                     False                      True
# 17                       False                      True
# 1236                     False                      True
# 585                      False                      True
# 1720                     False                      True
# 1268                     False                      True
# 10                       False                      True
# 2512                     False                      True
# 3211                     False                      True
# 386                      False                      True
# 2832                     False                      True
# 165                      False                      True
# 679                      False                      True
# 121                      False                      True
# 334                      False                      True
# 1034                     False                      True

# %% [markdown]
# <h1>End of Data Cleaning</h1>

# %% [markdown]
# ## Q1:
#
# Solution:

# %% [markdown]
# <h3> Abbreviations</h3>
# <p> wrt => with respect to</p>
# <p> r = regardless of</p>

# %% [markdown]
# <b> A) Analyze the distribution of death events cases among the patients and the race. calculate their respective numbers and percentages. (0.5 points)<

# %%
total_count_wrt_race = df_verThree['race'].value_counts()

# %%
death_cases_wrt_race = df_verThree.groupby(['race'])['status_Dead'].sum()

# %%
percentage_of_death_cases_wrt_race = round((death_cases_wrt_race / total_count_wrt_race) * 100,2)

# %%
percentage_of_death_cases_r_race = round(death_cases_wrt_race / total_count_r_race * 100,2 )

# %%
total_count_wrt_race = pd.DataFrame(total_count_wrt_race).rename(columns = {'count':'Total People'})
total_count_wrt_race
# Out:
#        Total People
# race
# White          3413
# Other           320
# Black           291

# %%
death_cases_wrt_race = pd.DataFrame(death_cases_wrt_race).rename(columns = {'status_Dead':'Number Of Deaths'})
death_cases_wrt_race
# Out:
#        Number Of Deaths
# race
# Black                73
# Other                33
# White               510

# %%
percentage_of_death_cases_wrt_race = pd.DataFrame(percentage_of_death_cases_wrt_race).rename(columns = {0:'Death Percentages'})
percentage_of_death_cases_wrt_race
# Out:
#        Death Percentages
# race
# Black              25.09
# Other              10.31
# White              14.94

# %% [markdown]
# <b>B) Compute descriptive statistics of the data. Comment on the results. (0.75 points)</b>

# %%
df_verThree.describe().T
# Out:
#                          count       mean        std   min   25%   50%   75%  \
# age                     4024.0  53.972167   8.963134  30.0  47.0  54.0  61.0
# tumor_size              4024.0  30.414016  21.139607   0.0  16.0  25.0  38.0
# regional_node_examined  4024.0  14.357107   8.099675   1.0   9.0  14.0  19.0
# regional_node_positive  4024.0   4.158052   5.109331   1.0   1.0   2.0   5.0
# survival_months         4024.0  71.176938  23.069683   0.0  56.0  73.0  90.0
#
#                           max
# age                      69.0
# tumor_size              140.0
# regional_node_examined   61.0
# regional_node_positive   46.0
# survival_months         107.0

# %% [markdown]
# <H3>Description</H3>
# <p><b>Age:</b></p>
# <p>    The average age of the patients is almost 54 years old. 25% of the patients are below 47 years of age, whereas 75% of the patients are above 61. The Maximum age of the patient is 69</p>
# <p><b>tumor_size:</b></p>
# <p>    </p>
# <p><b>regional_node_examined:</b></p>
# <p>    </p>
# <p><b>regional_node_positive: </b></p>
# <p>    </p>
# <p><b>survival_months: </b></p>

# %% [markdown]
# <b>C) Analyze the skew and the kurtosis of medical variables distributions(Numbers & Graphs). Comment on the results. (0.75 points)</b>

# %% [markdown]
# <h3>Numbers</h3>

# %%
medical_numerical_colums = df_verThree.select_dtypes(include=[np.number])
medical_numerical_colums.agg(['skew','kurtosis']).T
# Out:
#                             skew  kurtosis
# age                    -0.220373 -0.755088
# tumor_size              1.738227  3.634147
# regional_node_examined  0.829274  1.649322
# regional_node_positive  2.702536  8.981266
# survival_months        -0.612032  0.076193

# %% [markdown]
# <h3>Graphs</h3>

# %%
tumor_size = df_verThree['tumor_size']
regional_node_examined = df_verThree['regional_node_examined']
regional_node_positive = df_verThree['regional_node_positive']
survival_months = df_verThree['survival_months']

# %%
plt.figure(figsize=(10,12))
plt.subplot(2,2,1)
sb.histplot(tumor_size, kde= True, bins = calculate_bin_edges(tumor_size,8));
plt.title('Hist Plot of Tumor Size');

plt.subplot(2,2,2)
sb.histplot(regional_node_examined, kde = True, bins = calculate_bin_edges(regional_node_examined,4))
plt.title('Hist Plot of Examination of Regional Node')

plt.subplot(2,2,3)
sb.histplot(survival_months, kde = True, bins = calculate_bin_edges(survival_months,8))
plt.title('Hist Plot of Examination of Survival Months')

plt.subplot(2,2,4)
sb.histplot(regional_node_positive, kde = True, bins = calculate_bin_edges(regional_node_positive,3))
plt.title('Hist Plot of Examination of Survival Months')
# Out:
# /home/ahmedhanifc/miniconda3/envs/learningDSAI/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/ahmedhanifc/miniconda3/envs/learningDSAI/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/ahmedhanifc/miniconda3/envs/learningDSAI/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/ahmedhanifc/miniconda3/envs/learningDSAI/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Hist Plot of Examination of Survival Months')

# %% [markdown]
# <P> The counts are not equal, so I need to standardize those</P>
# <h2> Comments</h2>
# <p><b>Tumor Size</b></p>
# <p>    </p>
# <p><b>Examination of Regional Mode</b></p>
# <p>    </p>
# <p><b>Positive Result of the Examination</b></p>
# <p>    </p>
# <p><b>Survival Months</b></p>
# <p>    </p>

# %%
def normalization(df):
    return (df - df.min()) / (df.max() - df.min())

# %% [markdown]
# ###  Q2:
# Solution:

# %% [markdown]
# <b>Use univariate plots to analyze patterns in each of the medical variables with respect to the outcome (death status). What categories of patients (race and marital status) were most likely to die from breast cancer? . (2 points)</b>

# %% [markdown]
# ###  Q3:

# %% [markdown]
# ###  Q4:
# Solution:

# %% [markdown]
# ###  Q5:

# %% [markdown]
# ###  Q6:

# %% [markdown]
# ###  Q7:

# %% [markdown]
# ###  Q8 :
# Solution

# %% [markdown]
# # Assignment 2 - Machine Learning Models for Prediction
# **(15 points total)**
#
#
# * In **Assignment 1**, we have explored the data, cleaned up the data, modified features, and created new ones.
# * In **Assignment 2**, we will apply supervised machine learning models for classification and regression, evaluate its perofrmance, and identify the best models to solve the following problems:
#
#     * The **classification problem** is: given a train dataset of patients who survived or did not survive, build a model which can determine based on a given test dataset not containing the death event information information, if these patients in the test dataset survived or not.
#
#     * The **regression problem** is: predict the number of months that remains for the survival of the patient.

# %% [markdown]
# **Question 1. (Data preparation)**  _(2 points)_
# * List the relevant features which you will use for classification and explain your answer (*a relevant feature is a feature that can have an impact on the chance of survival of the patient*).
# * List the relevant features which you will use for regression and explain your answer (*a relevant feature is a feature that can have an impact on the prediction of the number of remaining survival months of the patient*).
# * Divide both your datasets into a training set (70%) and a testing set (30%). All models will be trained and tested on the same splits.

# %% [markdown]
# ###  Data Preparation & Spliting for the Classification Model

# %% [markdown]
# ###  Data Preparation & Spliting for the Regression Model

# %% [markdown]
# **Question 2. (Classification models)**  _(3 points)_
# * Train three different classification models of your choice using the training set. Explain the rationale behind selecting each of these three algorithms. You may refer to the following guidlines for model selection:
#     * Diagram from scikit-learn: https://scikit-learn.org/stable/tutorial/machine_learning_map/
#     * Models comparison table: https://docs.google.com/spreadsheets/d/16i47Wmjpj8k-mFRk-NnXXU5tmSQz8h37YxluDV8Zy9U/edit#gid=0

# %% [markdown]
# **Question 3. (Evaluation of classification models)**  _(3 points)_
# * Evaluate the performance of your three classification models on the testing set using the following metrics: accuracy, area under the curve (AUC), precision, and recall.
# * Based on the models evaluation results, what is the best model and why?

# %% [markdown]
# **Question 4. (Regression models)**  _(3 points)_
# * Train two different regression models of your choice using the training set. Explain the rationale behind selecting each of these two algorithms.

# %% [markdown]
# **Question 5. (Evaluation of regression models)**  _(3 points)_
# * Evaluate the performance of your two regression models on the testing set using the following metrics: mean absolute error,mean squared error, and R-square.
# * Based on the models evaluation results, what is the best model and why?

# %% [markdown]
# **Question 6. (Possible improvements)** _(1 points)_
# * How can you improve the accuracy of your classification model?
# * How can you improve the accuracy of your regression model?

# %% [markdown]
# <h1>References</h1>

# %% [markdown]
# <p>
#     GfG. (2020, December 11). How to reset index after Groupby pandas? GeeksforGeeks. https://www.geeksforgeeks.org/how-to-reset-index-after-groupby-pandas/
#
# </p>
